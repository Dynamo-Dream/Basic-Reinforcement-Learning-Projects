# %%
import gym
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make("CarRacing-v2", domain_randomize=True)

# %%
# !pip install box2d box2d-kengz --user
# Out:
# ...
#      ---------------------------------------- 0.0/425.4 kB ? eta -:--:--
#       --------------------------------------- 10.2/425.4 kB ? eta -:--:--
#       --------------------------------------- 10.2/425.4 kB ? eta -:--:--
#       --------------------------------------- 10.2/425.4 kB ? eta -:--:--
#      -- ---------------------------------- 30.7/425.4 kB 145.2 kB/s eta 0:00:03
#      -- ---------------------------------- 30.7/425.4 kB 145.2 kB/s eta 0:00:03
#      -- ---------------------------------- 30.7/425.4 kB 145.2 kB/s eta 0:00:03
#      -- ---------------------------------- 30.7/425.4 kB 145.2 kB/s eta 0:00:03
#      -- ---------------------------------- 30.7/425.4 kB 145.2 kB/s eta 0:00:03
#      -- ---------------------------------- 30.7/425.4 kB 145.2 kB/s eta 0:00:03
#      -- ---------------------------------- 30.7/425.4 kB 145.2 kB/s eta 0:00:03
#      -- ---------------------------------- 30.7/425.4 kB 145.2 kB/s eta 0:00:03
# ...

# %%
# !pip install --upgrade wheel
# Out:
# ...
#   Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/b8/8b/31273bf66016be6ad22bb7345c37ff350276cfd46e389a0c2ac5da9d9073/wheel-0.41.2-py3-none-any.whl.metadata
#   Using cached wheel-0.41.2-py3-none-any.whl.metadata (2.2 kB)
# Using cached wheel-0.41.2-py3-none-any.whl (64 kB)
# ...
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.38.4
#     Uninstalling wheel-0.38.4:
#       Successfully uninstalled wheel-0.38.4
# ...

# %%
# !pip install --upgrade pip

# %%
# !pip install swig
# Out:
# ...
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 MB 163.8 kB/s eta 0:00:15
#      ---------------------------------------- 0.0/2.5 MB 163.8 kB/s eta 0:00:15
#       --------------------------------------- 0.0/2.5 MB 178.6 kB/s eta 0:00:14
#      - -------------------------------------- 0.1/2.5 MB 348.6 kB/s eta 0:00:07
#      -- ------------------------------------- 0.2/2.5 MB 508.4 kB/s eta 0:00:05
#      ---- ----------------------------------- 0.3/2.5 MB 774.0 kB/s eta 0:00:03
#      ----- ---------------------------------- 0.4/2.5 MB 955.7 kB/s eta 0:00:03
#      --------- ------------------------------ 0.6/2.5 MB 1.3 MB/s eta 0:00:02
#      ------------ --------------------------- 0.8/2.5 MB 1.7 MB/s eta 0:00:02
# ...

# %%
env = gym.make("CarRacing-v2", domain_randomize=True, render_mode = "human")

# %%
episodes = 5

for i in range(1,episodes+1):
    observation,info = env.reset()
    score = 0
    while True:
        action = env.action_space.sample()
        observation, reward, terminated, truncated, info = env.step(action)
        score+=reward
        if terminated or truncated:
            observation,info = env.reset()
            break
    print("Episode: {} Score: {}".format(i, score))
# Out:
# C:\Users\manis\anaconda3\envs\whoisboss\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode: 1 Score: -34.21052631579005
# Episode: 2 Score: -20.634920634920615
# Episode: 3 Score: -30.555555555555998
# Episode: 4 Score: -33.993399339934584
# Episode: 5 Score: -30.795847750865498

# %% [markdown]
# #### env.action_space

# %%
import pygame
width, height = 64, 64  # Replace with your desired values

# Initialize Pygame
pygame.init()

# Create the display surface with the specified width and height
screen = pygame.display.set_mode((width, height))

# %%
env.close()

# %%
vec_env = gym.make("CarRacing-v2", render_mode = "human")
vec_env = DummyVecEnv([lambda: env])
# Out:
# C:\Users\manis\anaconda3\envs\whoisboss\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
log_path = os.path.join("Training", "Logs")
model = PPO("CnnPolicy", vec_env, verbose = 1,tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training\Logs\PPO_9
# C:\Users\manis\anaconda3\envs\whoisboss\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -----------------------------
# | time/              |      |
# |    fps             | 15   |
# |    iterations      | 1    |
# |    time_elapsed    | 129  |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 2           |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009127533 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# ...

# %%
evaluate_policy(model,env,n_eval_episodes=10,render=True)
# Out:
# C:\Users\manis\anaconda3\envs\whoisboss\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\manis\anaconda3\envs\whoisboss\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-47.55222095996142, 28.06414670892406)
